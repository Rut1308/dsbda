# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Amazonbookreviews.csv')

# %%
data
# Out:
#          reviewerID      asin reviewername  helpful  \
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1    A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2    A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3    A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4    A1SUAM1J3GNN3B     123.0      PRANOTI        3
# 5   BA2345WERSDFRER  236789.0      SHALINI        3
# 6   CADERVG3450EREW       NaN       SNEHAL        3
# 7   ASDF345671QWERT  224442.0       SHIKHA        3
# 8     MNHJ879WERFGH   98767.0       AKSHAY        2
# 9    1234ZSDFREQWEG   78761.0       SATISH        2
# 10   9345GHIKLFLLED  321456.0         RAJU        2
# 11              NaN  876231.0        ROHIT        2
# 12   HGKIUYE345SFDG     987.0        MOHIT        2
# 13  NIKRT2398701222     234.0       NILESH        2
# 14   MAHI2348900122     124.0      KAILASH        2
# 15   LIHJKD87634O21     156.0        SONAM        2
# 16  SISISWER4657893     876.0       RAJESH        2
# ...

# %%
data.head()
# Out:
#        reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# ...

# %%
data.tail()
# Out:
#       reviewerID     asin reviewername  helpful           reviewerText  \
# 40   67FDASAA123   2312.0      NANAJJI        3            BYE MY LOVE
# 41     ASWER1234   1222.0       PREETI        2                LOVE U
# 42    QWCVFED123  11111.0        DHONI        2             HELLO DEAR
# 43   123LKIUHNFG   9800.0         MAHI        2  DAER PLEASE READ BOOK
# 44  987DFHGJI657      NaN          DDE        2                   BOOK
#
#     overallRating       Summary  UnixreviewTime  reviewTime
# 40            4.0  HELL OF HELL             NaN         NaN
# 41            4.0          DEAA             NaN         NaN
# 42            4.0   DEAR TO ALL             NaN         NaN
# 43            4.0       MOTHER              NaN         NaN
# 44            4.0  WINE OF WINE             NaN         NaN

# %%
data.describe()
# Out:
#                 asin    helpful  overallRating  UnixreviewTime  reviewTime
# count      43.000000  45.000000      45.000000             0.0         0.0
# mean    69702.023256   2.533333       3.282222             NaN         NaN
# std    193175.237815   0.504525       0.816113             NaN         NaN
# min         1.000000   2.000000       2.000000             NaN         NaN
# 25%       140.000000   2.000000       3.000000             NaN         NaN
# 50%      2121.000000   3.000000       3.000000             NaN         NaN
# 75%     22350.500000   3.000000       4.000000             NaN         NaN
# max    879877.000000   3.000000       5.000000             NaN         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      43 non-null     object
#  1   asin            43 non-null     float64
#  2   reviewername    44 non-null     object
#  3   helpful         45 non-null     int64
#  4   reviewerText    45 non-null     object
#  5   overallRating   45 non-null     float64
#  6   Summary         45 non-null     object
#  7   UnixreviewTime  0 non-null      float64
#  8   reviewTime      0 non-null      float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.3+ KB

# %%
data.shape
# Out:
# (45, 9)

# %%
data.isnull()
# Out:
#     reviewerID   asin  reviewername  helpful  reviewerText  overallRating  \
# 0        False  False         False    False         False          False
# 1        False  False         False    False         False          False
# 2        False  False         False    False         False          False
# 3        False  False         False    False         False          False
# 4        False  False         False    False         False          False
# 5        False  False         False    False         False          False
# 6        False   True         False    False         False          False
# 7        False  False         False    False         False          False
# 8        False  False         False    False         False          False
# 9        False  False         False    False         False          False
# 10       False  False         False    False         False          False
# 11        True  False         False    False         False          False
# ...

# %%
data.isnull().sum()
# Out:
# reviewerID         2
# asin               2
# reviewername       1
# helpful            0
# reviewerText       0
# overallRating      0
# Summary            0
# UnixreviewTime    45
# reviewTime        45
# dtype: int64

# %%
#creating subsets row wise

df1 = data[['reviewerID','reviewername','reviewerText','overallRating']].loc[0:15]
df1
# Out:
#          reviewerID reviewername  \
# 0    A2SUAM1J3GNN3B        SNEHA
# 1    A2SUAN1J3GNN0C      KARTHII
# 2    A2SUAN1J3GNN7B     SHASHANK
# 3    A5SUAN1J3GNN9B        NITIN
# 4    A1SUAM1J3GNN3B      PRANOTI
# 5   BA2345WERSDFRER      SHALINI
# 6   CADERVG3450EREW       SNEHAL
# 7   ASDF345671QWERT       SHIKHA
# 8     MNHJ879WERFGH       AKSHAY
# 9    1234ZSDFREQWEG       SATISH
# 10   9345GHIKLFLLED         RAJU
# 11              NaN        ROHIT
# 12   HGKIUYE345SFDG        MOHIT
# 13  NIKRT2398701222       NILESH
# 14   MAHI2348900122      KAILASH
# 15   LIHJKD87634O21        SONAM
#
#                                          reviewerText  overallRating
# 0   I bought this for my husband who plays the pia...            4.0
# 1                                   good book to read            3.0
# 2                                           high cost            2.5
# 3                                     good useof book            2.2
# ...

# %%
df2 = data[['reviewerID','reviewername','reviewerText','overallRating']].loc[16:30]
df2
# Out:
#          reviewerID reviewername        reviewerText  overallRating
# 16  SISISWER4657893       RAJESH       money is dis             3.0
# 17   MIKI23412341QW       SALMAN    stare the raeder            2.0
# 18   AAAJI37DFG378I       PANKAJ     reader is giood            2.0
# 19   FAJI234GAJI987        DIPTI             faskjas            2.0
# 20    VABI9876ERTT1       MANISH               fdghi            2.0
# 21   NIKI12NIKI1231       SHREYA           dvdasaewb            4.0
# 22   MIKISDF1232XAD    AISHWARYA                 NA             4.0
# 23     GHAU8768QWER       SUMEET                 NA             4.0
# 24   NIKI12NIKI1231      PRAJWAL                 NA             4.0
# 25   MIKISDF1232XAD        JACOB         0.888888888            4.0
# 26     GHAU8768QWER       MARYLS         9.666666667            4.0
# 27  BA2345WERSDFRER        CHRIS             helpful            4.0
# 28  CADERVG3450EREW       MORRIS       staff is good            4.0
# ...

# %%
df3 = data[['reviewerID','reviewername','reviewerText','overallRating']].loc[31:44]
df3
# Out:
#          reviewerID reviewername           reviewerText  overallRating
# 31   1234ZSDFREQWEG       VARSHA       stare the raeder            4.0
# 32   9345GHIKLFLLED     SHRADDHA        reader is giood            3.0
# 33              NaN         SAIF                faskjas            3.0
# 34   HGKIUYE345SFDG       KRISSH                  fdghi            3.0
# 35  NIKRT2398701222         NEIL               8.78E+21            3.0
# 36   MAHI2348900122      KANGANA                  67667            2.0
# 37   LIHJKD87634O21        KHANN                3434567            2.0
# 38  SISISWER4657893        RIYAA                   098O            2.0
# 39     8786112GHAUI          NaN              GOOD LUCK            2.0
# 40      67FDASAA123      NANAJJI            BYE MY LOVE            4.0
# 41        ASWER1234       PREETI                LOVE U             4.0
# 42       QWCVFED123        DHONI             HELLO DEAR            4.0
# ...

# %%
#column wise
amazon_subset1 = data[['reviewerID', 'overallRating', 'reviewerText']]
amazon_subset1
# Out:
#          reviewerID  overallRating  \
# 0    A2SUAM1J3GNN3B            4.0
# 1    A2SUAN1J3GNN0C            3.0
# 2    A2SUAN1J3GNN7B            2.5
# 3    A5SUAN1J3GNN9B            2.2
# 4    A1SUAM1J3GNN3B            3.0
# 5   BA2345WERSDFRER            3.0
# 6   CADERVG3450EREW            3.0
# 7   ASDF345671QWERT            3.0
# 8     MNHJ879WERFGH            3.0
# 9    1234ZSDFREQWEG            5.0
# 10   9345GHIKLFLLED            4.0
# 11              NaN            4.0
# 12   HGKIUYE345SFDG            4.0
# 13  NIKRT2398701222            3.0
# 14   MAHI2348900122            3.0
# 15   LIHJKD87634O21            3.0
# 16  SISISWER4657893            3.0
# 17   MIKI23412341QW            2.0
# 18   AAAJI37DFG378I            2.0
# 19   FAJI234GAJI987            2.0
# 20    VABI9876ERTT1            2.0
# 21   NIKI12NIKI1231            4.0
# 22   MIKISDF1232XAD            4.0
# 23     GHAU8768QWER            4.0
# 24   NIKI12NIKI1231            4.0
# ...

# %%
amazon_subset2 = data[['helpful','Summary','reviewername']]
amazon_subset2
# Out:
#     helpful                Summary reviewername
# 0         2            SUBWAY SURF        SNEHA
# 1         3                 PILOT       KARTHII
# 2         3        DRIVE IN HEAVEN     SHASHANK
# 3         3          SPORTS HEAVEN        NITIN
# 4         3       HEAVEN OF PEARLS      PRANOTI
# 5         3              GODS GIFT      SHALINI
# 6         3            GODESS LIFE       SNEHAL
# 7         3            LIFE OF PIE       SHIKHA
# 8         2  INDIA A MASSIVE POWER       AKSHAY
# 9         2           DATA IS DATA       SATISH
# 10        2  INDIA A MASSIVE POWER         RAJU
# 11        2           FRIENDS HELP        ROHIT
# 12        2           MOTIVATIONAL        MOHIT
# 13        2            DARK KNIGHT       NILESH
# 14        2           HELL OF HELL      KAILASH
# 15        2                   DEAA        SONAM
# 16        2            DEAR TO ALL       RAJESH
# 17        2                MOTHER        SALMAN
# 18        2           WINE OF WINE       PANKAJ
# ...

# %%
#merging of data row wise
merge = pd.concat([df1,df2,df3])
merge
# Out:
#          reviewerID reviewername  \
# 0    A2SUAM1J3GNN3B        SNEHA
# 1    A2SUAN1J3GNN0C      KARTHII
# 2    A2SUAN1J3GNN7B     SHASHANK
# 3    A5SUAN1J3GNN9B        NITIN
# 4    A1SUAM1J3GNN3B      PRANOTI
# 5   BA2345WERSDFRER      SHALINI
# 6   CADERVG3450EREW       SNEHAL
# 7   ASDF345671QWERT       SHIKHA
# 8     MNHJ879WERFGH       AKSHAY
# 9    1234ZSDFREQWEG       SATISH
# 10   9345GHIKLFLLED         RAJU
# 11              NaN        ROHIT
# 12   HGKIUYE345SFDG        MOHIT
# 13  NIKRT2398701222       NILESH
# 14   MAHI2348900122      KAILASH
# 15   LIHJKD87634O21        SONAM
# 16  SISISWER4657893       RAJESH
# 17   MIKI23412341QW       SALMAN
# 18   AAAJI37DFG378I       PANKAJ
# 19   FAJI234GAJI987        DIPTI
# 20    VABI9876ERTT1       MANISH
# 21   NIKI12NIKI1231       SHREYA
# 22   MIKISDF1232XAD    AISHWARYA
# 23     GHAU8768QWER       SUMEET
# 24   NIKI12NIKI1231      PRAJWAL
# 25   MIKISDF1232XAD        JACOB
# 26     GHAU8768QWER       MARYLS
# ...

# %%
#merge column wise
merge = pd.concat([amazon_subset1,amazon_subset2])
merge
# Out:
#         reviewerID  overallRating  \
# 0   A2SUAM1J3GNN3B            4.0
# 1   A2SUAN1J3GNN0C            3.0
# 2   A2SUAN1J3GNN7B            2.5
# 3   A5SUAN1J3GNN9B            2.2
# 4   A1SUAM1J3GNN3B            3.0
# ..             ...            ...
# 40             NaN            NaN
# 41             NaN            NaN
# 42             NaN            NaN
# 43             NaN            NaN
# 44             NaN            NaN
#
#                                          reviewerText  helpful       Summary  \
# 0   I bought this for my husband who plays the pia...      NaN           NaN
# 1                                   good book to read      NaN           NaN
# 2                                           high cost      NaN           NaN
# 3                                     good useof book      NaN           NaN
# 4                             I m happy with the book      NaN           NaN
# ..                                                ...      ...           ...
# ...

# %%
sort = data.sort_values('overallRating', ascending = False)
sort
# Out:
#          reviewerID      asin reviewername  helpful  \
# 9    1234ZSDFREQWEG   78761.0       SATISH        2
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 21   NIKI12NIKI1231    3451.0       SHREYA        2
# 43      123LKIUHNFG    9800.0         MAHI        2
# 42       QWCVFED123   11111.0        DHONI        2
# 41        ASWER1234    1222.0       PREETI        2
# 40      67FDASAA123    2312.0      NANAJJI        3
# 31   1234ZSDFREQWEG      21.0       VARSHA        3
# 30    MNHJ879WERFGH   21221.0         JOHN        3
# 29  ASDF345671QWERT      23.0        HARRY        3
# 28  CADERVG3450EREW      11.0       MORRIS        3
# 27  BA2345WERSDFRER      11.0        CHRIS        3
# 26     GHAU8768QWER      23.0       MARYLS        3
# 25   MIKISDF1232XAD       1.0        JACOB        3
# 24   NIKI12NIKI1231       2.0      PRAJWAL        3
# 23     GHAU8768QWER     321.0       SUMEET        2
# 22   MIKISDF1232XAD     879.0    AISHWARYA        2
# ...

# %%
df1.transpose()
# Out:
#                                                               0   \
# reviewerID                                        A2SUAM1J3GNN3B
# reviewername                                               SNEHA
# reviewerText   I bought this for my husband who plays the pia...
# overallRating                                                4.0
#
#                               1               2                3   \
# reviewerID        A2SUAN1J3GNN0C  A2SUAN1J3GNN7B   A5SUAN1J3GNN9B
# reviewername             KARTHII        SHASHANK            NITIN
# reviewerText   good book to read       high cost  good useof book
# overallRating                3.0             2.5              2.2
#
#                                     4   \
# reviewerID              A1SUAM1J3GNN3B
# reviewername                   PRANOTI
# reviewerText   I m happy with the book
# overallRating                      3.0
#
#                                                    5                6   \
# ...

# %%
shaping=data.shape
shaping
# Out:
# (45, 9)

# %%
pivot_table = pd.pivot_table(data,index = ['reviewername','reviewerText'], values = 'overallRating')
print(pivot_table)
# Out:
#                                                                  overallRating
# reviewername reviewerText
# AISHWARYA    NA                                                            4.0
# AKSHAY       The music is at times hard to read because we t...            3.0
# CHRIS        helpful                                                       4.0
# DDE          BOOK                                                          4.0
# DHONI        HELLO DEAR                                                    4.0
# DIPTI        faskjas                                                       2.0
# HARRY        good buy for money                                            4.0
# JACOB        0.888888888                                                   4.0
# JOHN         money is dis                                                  4.0
# KAILASH      staff is good                                                 3.0
# KANGANA      67667                                                         2.0
# ...
